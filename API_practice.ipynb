# %%
# Create a practice set of random latitude and longitude combinations.

lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
# Before this, we installed citipy to our PythonData environment by launching in anaconda prompt to install module

# Use the citipy module to determine city based on latitude and longitude.

from citipy import citipy

# copied stright from lesson

# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Was missing the coordinates variable, picked it up from other JNB and added here

# %%
# # Import the requests library

import requests

# Import the API key

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.  BOSTON IS MISSPELLED
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather

# Regarding '200' below, When we receive a valid response from the server, we have to decide on the data format
# The options are text, JSON, XML, or HTML format. We can apply the format attributes to get the data into a useful
# format to parse.

# One format that provides a preview of the JSON data is the text attribute.
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"base":"stations","main":{"temp":31.71,"feels_like":21.24,"temp_min":27.19,"temp_max":35.56,"pressure":1030,"humidity":67},"visibility":10000,"wind":{"speed":14.97,"deg":10},"clouds":{"all":100},"dt":1670734961,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1670760209,"sunset":1670793107},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 31.71,
#   'feels_like': 21.24,
#   'temp_min': 27.19,
#   'temp_max': 35.56,
#   'pressure': 1030,
#   'humidity': 67},
#  'visibility': 10000,
#  'wind': {'speed': 14.97, 'deg': 10},
#  'clouds': {'all': 100},
#  'dt': 1670734961,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1670760209,
#   'sunset': 1670793107},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 31.71,
#   'feels_like': 21.24,
#   'temp_min': 27.19,
#   'temp_max': 35.56,
#   'pressure': 1030,
#   'humidity': 67},
#  'visibility': 10000,
#  'wind': {'speed': 14.97, 'deg': 10},
#  'clouds': {'all': 100},
#  'dt': 1670734961,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1670760209,
#   'sunset': 1670793107},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
# Using sys key to get the corresponding value, we type 
boston_data['sys']
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1670760209,
#  'sunset': 1670793107}

# %%
# Now run adding the country key in brackets after sys key and US will be returned in output
boston_data['sys']['country']
# Out:
# 'US'

# %%
# to get the date - in a time of day in seconds in a database timestamp format
boston_data['dt']
# Out:
# 1670734961

# %%
# Using similar syntax to get the time of day, we can get the latitude, longitude, maximum temperature,
# humidity, percent cloudiness, and wind speed

lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 35.56 67 100 14.97

# %%
# Convert the date timestamp - the date format appears in seconds boston_data['dt'] output - 1571678675

# This format is called Coordinated Universal Time (UTC) or Greenwich Mean Time (GMT).
# If we want to convert the timestamp to the International Organization for Standardization (ISO) format,
# or YYYY-MM-DD-HH-MM-SS, we need to use the Python datetime module

# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 12, 11, 5, 2, 41)

# %%
# We can convert this datetime format to 2019-10-21 17:24:35 using the Python string format method strftime()
# and adding how we want the string to look inside the parentheses. In our case, we would use
# strftime('%Y-%m-%d %H:%M:%S')
# Add .strftime('%Y-%m-%d %H:%M:%S') to the end of the conversion 
# datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S') Rerun the cell
# The output should look like the following.

# '2019-10-21 17:24:35'

# %%
# from 6.2.6 

# Import the time library and the datetime module from the datetime library

# import time
# from datetime import datetime

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
#######    adding this because I have an error 'cities' is not defined  ############   hope it works
#######    had to add 'coordinates' to just like when I had error during early start of API_practice

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21068\2935622200.py in <module>
#       6 # Identify the nearest city for each latitude and longitude combination.
#       7 for coordinate in coordinates:
# ----> 8     city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
#       9
#      10     # If the city is unique, then we will add it to the cities list.
#
# NameError: name 'citipy' is not defined

# %%
# Import dependencies

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
###############  adding this from WeatherPy because it was reading piece with only 5 city coordinates above
############### remarked it out

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# The following is the zip packing and unpacking tests from 6.1.4 (after adding code to API_pratice)

# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

#You can only unzip a zipped tuple once before it is removed from the computer's memory.
# Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Use the print() function to display the latitude and longitude combinations.

for coordinate in coordinates:
    
    print(coordinate[0], coordinate[1])
    
# When we run this cell, the output is ordered pairs of our lats and lngs coordinates.
# Out:
# -22.770568455821888 41.85199243588741
# -59.7106740073493 -179.5615112886105
# -53.06577844078069 -149.72935844890333
# 35.562376993009835 60.62235368743086
# -10.955985632674668 -108.32331102497027
# 83.39754473126146 -31.65741982554212
# -20.407657457140374 -111.18362683609192
# 23.741362765560552 94.53737041951536
# 47.07705781684038 150.60941573673523
# 86.541582613376 -137.0993283032618
# -35.83974816934058 -33.35197870043649
# 52.702313142954296 -142.71634972070882
# -38.82765285333076 -12.906887756483115
# 80.76303007476494 -123.17952604060977
# 9.138051832658775 145.26467558340062
# -51.236313488128644 131.76640951445933
# -12.840348226832688 -178.21668500694096
# 76.9923132327308 -159.76151688186266
# 22.01205750471763 151.86858071672486
# -27.93054881005886 -58.443861056847126
# -62.10156604438782 -39.55409535051061
# -65.8782866507042 -27.992213039567275
# 66.67599284035109 109.22118745484016
# 26.98008370105164 -3.2812545995358846
# 47.4263851139828 85.33292826835321
# ...

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# adding on to the code block as instructed 6.2.6

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# adding the enumerate() method 
# for i, item in enumerate(list):

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 0

# %%
# can't get code above to run. copied over code from other file to see if I could 
# get the code and city_data arry of dictionaries to run, but can't figure it out
# is this because I didn't create a DataFrame?
# watch videos of class tomorrow
