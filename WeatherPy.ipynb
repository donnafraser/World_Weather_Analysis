# %%
# Import dependencies

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# creating arrays of latitudes and longitudes, we'll declare each array as a variable
# in here, we will also use the zip() function to pack the lats and lngs as pairs by zipping them

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

lat_lngs

# When we run this cell, the output is a zip object in memory

# %%
# The following is the zip packing and unpacking tests from 6.1.4 (after adding code to API_pratice)

# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

#You can only unzip a zipped tuple once before it is removed from the computer's memory.
# Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Use the print() function to display the latitude and longitude combinations.

for coordinate in coordinates:
    
    print(coordinate[0], coordinate[1])
    
# When we run this cell, the output is ordered pairs of our lats and lngs coordinates.
# Out:
# -83.36213648732068 -142.05129911419755
# -28.781617745197735 44.4196859238788
# 12.853853548145949 -110.90484050642029
# 70.80083743588972 -20.41030594883597
# -77.62332872709062 7.160768586148151
# 25.483962382451168 -90.34206282064576
# -43.50638117482415 -159.67049035667034
# 47.78844113122648 -53.2376455528977
# 43.318097675579054 123.73734681382098
# 11.637169963558051 -160.97927596035626
# -88.7096849584196 75.69837365707738
# -28.74023750918235 143.02737158228496
# 23.749748392823577 -118.51208523242917
# -66.90310609765876 120.39345810928376
# 48.972501862190995 -149.99174225560046
# 19.073731783553768 118.99283373392348
# -31.75356431382911 28.194999548853104
# 3.9948682179623916 84.03768422459206
# -8.880502283100796 125.3041096081879
# -18.05071545956244 -31.538681564068042
# -88.3503278015625 110.9011879051933
# 25.536940028488516 155.6074423670329
# -24.81528778967153 -3.6516710684871896
# 29.96945848208253 28.463849970080332
# 75.53515492959389 -109.53508767614511
# ...

# %%
# Citipy doesn't come with the Anaconda module, so we'll install it in our PythonData environment

# launched PythonData Anaconda Prompt and copied and pasted pip install citipy

# %%
# encountered error in API_practice so I am moving on here to iterate through zipped lat_lngs tuples

# %%
from citipy import citipy

# %%
# copying from text in lesson to be sure the error is not mine, i've remarked my attempt above

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)


# create a list for holding the cities

#cities  = []

# identify the nearest city for each latitude and longitude combo

#for coordinate in coordinates:
    
    #city = citipy.nearest_city(coordinate[0], coordinate[1].city_name)
    
    # if the city is unique, then we will add it to the cities list
    
    #if city not in cities:
        
        #cities.append(city)
        
#print the city count to confirm sufficient count

#len(cities)
# Out:
# 594

# %%
len(cities)
# Out:
# 594

# %%
# copying from text in lesson to be sure the error is not mine, i've remarked my attempt above

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 594

# %%
# Yay!!!! It worked!!! Can trouble shoot later! :) NOW trying to update to GitHub

# %%
# after troubleshooting and looking for errors, I realize that at the start of 6.2.6, it states, without 
# bold/special text to "now work in our WeatherPy.ipynb file" OMG!

# starting over for 3rd time.......

# using instructions to import requests library and weather_api_key
# build the basic URL for the OpenWeatherMap with my weather_api_key and added URL - copied below from API_practice 

# # Import the requests library

import requests

# Import the API key

from config import weather_api_key

# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# print (url)

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
 # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1   
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 12 | mataura
# Processing Record 2 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 12 | san patricio
# Processing Record 4 of Set 12 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 12 | hermanus
# Processing Record 6 of Set 12 | houma
# Processing Record 7 of Set 12 | avarua
# Processing Record 8 of Set 12 | carbonear
# Processing Record 9 of Set 12 | zhengjiatun
# Processing Record 10 of Set 12 | hilo
# Processing Record 11 of Set 12 | busselton
# Processing Record 12 of Set 12 | broken hill
# Processing Record 13 of Set 12 | guerrero negro
# Processing Record 14 of Set 12 | albany
# Processing Record 15 of Set 12 | kodiak
# Processing Record 16 of Set 12 | davila
# Processing Record 17 of Set 12 | elliot
# Processing Record 18 of Set 12 | hambantota
# Processing Record 19 of Set 12 | atambua
# Processing Record 20 of Set 12 | belmonte
# ...

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using
# df = pd.DataFrame(list with dictionaries)

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     52.38        97          73
# 1  San Patricio  28.0170  -97.5169     78.87        64           7
# 2      Hermanus -34.4187   19.2345     71.80        90          74
# 3         Houma  29.5958  -90.7195     73.40       100         100
# 4        Avarua -21.2078 -159.7750     73.45        68          20
# 5     Carbonear  47.7332  -53.2148     33.60        87          99
# 6   Zhengjiatun  43.5064  123.5064     21.54        45         100
# 7          Hilo  19.7297 -155.0900     69.28        94          20
# 8     Busselton -33.6500  115.3333     54.01        67           0
# 9   Broken Hill -31.9500  141.4333     56.93        52          28
#
#    Wind Speed Country                 Date
# 0        0.98      NZ  2022-12-11 17:31:18
# 1        5.44      US  2022-12-11 17:28:44
# 2       17.63      ZA  2022-12-11 17:31:19
# 3        9.22      US  2022-12-11 17:31:19
# ...

# %%
# Recall that to reorder the columns, we assign a variable to an array of the columns in the order we
# want them to appear:
# new_column_order = ["column2", "column4", "column1"]
# Then, we assign a new or the same DataFrame with new column order:
# df = df[new_column_order]

new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# new_column_order = ["column1", "column8", "column9", "column2", "column3", "column4", "column5", "column6", "column7"]

# new_column_order = [1,8,9,2,3,4,5,6,7]

# city_data_df = city_data_df[new_column_order]

city_data_reorder = city_data_reorder[new_column_order]

# nothing got changed ??? Not sure what to do
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3404\1390962298.py in <module>
#      13 # city_data_df = city_data_df[new_column_order]
#      14
# ---> 15 city_data_reorder = city_data_reorder[new_column_order]
#      16
#      17 # nothing got changed ??? Not sure what to do
#
# NameError: name 'city_data_reorder' is not defined

# %%
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0       Mataura      NZ  2022-12-11 17:31:18 -46.1927  168.8643     52.38
# 1  San Patricio      US  2022-12-11 17:28:44  28.0170  -97.5169     78.87
# 2      Hermanus      ZA  2022-12-11 17:31:19 -34.4187   19.2345     71.80
# 3         Houma      US  2022-12-11 17:31:19  29.5958  -90.7195     73.40
# 4        Avarua      CK  2022-12-11 17:31:20 -21.2078 -159.7750     73.45
# 5     Carbonear      CA  2022-12-11 17:31:20  47.7332  -53.2148     33.60
# 6   Zhengjiatun      CN  2022-12-11 17:31:20  43.5064  123.5064     21.54
# 7          Hilo      US  2022-12-11 17:30:50  19.7297 -155.0900     69.28
# 8     Busselton      AU  2022-12-11 17:31:21 -33.6500  115.3333     54.01
# 9   Broken Hill      AU  2022-12-11 17:31:21 -31.9500  141.4333     56.93
#
#    Humidity  Cloudiness  Wind Speed
# 0        97          73        0.98
# 1        64           7        5.44
# 2        90          74       17.63
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Tried to perform git status
# git add
